# %% [markdown]
# ## 생능출판사 (가칭)"데이터과학 파이썬" 코드 13장

# %% [markdown]
# ## 13.2 맷플롯립으로 간단히 이미지 그려보기

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('d:/data/mandrill.png')
print(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-d8576c78c0e9> in <module>()
#       2 import matplotlib.image as mpimg
#       3
# ----> 4 img = mpimg.imread('d:/data/mandrill.png')
#       5 print(img)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in imread(fname, format)
#    1472             fd = BytesIO(request.urlopen(fname).read())
#    1473             return _png.read_png(fd)
# -> 1474     with cbook.open_file_cm(fname, "rb") as file:
#    1475         return _png.read_png(file)
#    1476
#
# /usr/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'd:/data/mandrill.png'

# %%
img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# ## 13.3 좀 더 편리한 이미지 도구는 없을까

# %%
% pip install opencv-python

# %%
import cv2

img_gray = cv2.imread('d:/data/mandrill.png', cv2.IMREAD_GRAYSCALE)
img_color = cv2.imread('d:/data/mandrill.png', cv2.IMREAD_COLOR)

cv2.imshow('grayscale', img_gray)
cv2.imshow('color image', img_color)

cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-3-a04ce74a3c07> in <module>()
#       4 img_color = cv2.imread('./images/mandrill.png', cv2.IMREAD_COLOR)
#       5
# ----> 6 cv2.imshow('grayscale', img_gray)
#       7 cv2.imshow('color image', img_color)
#       8
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %% [markdown]
# ## 13.4 OpenCV로 이미지 다루어 보자

# %%
cv2.line( 이미지, 시작지점 좌표, 끝지점 좌표, 색상, 굵기, 선의 종류, 좌표 시프트)

# %%
import cv2
img = cv2.imread('d:/data/mandrill.png', 1)
cv2.line(img, (0,0), (200,200), (0,0,255), 5)
cv2.arrowedLine(img, (0,200), (200,20), (0,0,255), 5)
cv2.imshow('lined', img)
cv2.waitKey(0)

# %%
cv2.rectangle(img, (0,200), (200,20), (0,0,0), 5)
cv2.putText(img, "hello", (70,70), fontFace = 2, fontScale = 1, color = (0,0,0))

# %% [markdown]
# ## 13.5 합성 사진을 제작해 보자

# %%
image_merged = cv2.addWeighted( image_a, weight_for_a, image_b, weight_for_b)

# %%
createTrackbar(조절할 값의 이름, 부착할 창 이름, 최소값, 최대값, 변경시 호출될 함수)

# %%
import cv2
global img1, img2

def on_change_weight(x):
    weight = x / 100
    img_merged = cv2.addWeighted(img1, 1-weight, img2, weight, 0)
    cv2.imshow('Display', img_merged)

cv2.namedWindow('Display')
cv2.createTrackbar('weight', 'Display', 0, 100, on_change_weight)

img1 = cv2.imread('./images/green_back.png')
img2 = cv2.imread('./images/iceberg.png')
img1 = cv2.resize(img1, (300,400))
img2 = cv2.resize(img2, (300,400))

cv2.imshow('Display', img1)
cv2.waitKey(0)

# %% [markdown]
# ## 13.6 이미지에 마스크를 씌워볼까

# %%
mask_image = cv2.imread('d:/data/mask_python.png')
back_image = cv2.imread('d:/data/iceberg.png')

# %%
mask_Inverted = cv2.bitwise_and(cv2.bitwise_not(mask_image), back_image)

# %%
import cv2
mask_image = cv2.imread('./images/mask_python.png')
back_image = cv2.imread('./images/iceberg.png')
mask_image = cv2.resize(mask_image, (300,400))
back_image = cv2.resize(back_image, (300,400))

mask_ANDed = cv2.bitwise_and(mask_image, back_image)
mask_ORed = cv2.bitwise_or(mask_image, back_image)
mask_XORed = cv2.bitwise_xor(mask_image, back_image)
mask_Inverted = cv2.bitwise_and(cv2.bitwise_not(mask_image), back_image)

cv2.imshow('mask', mask_image)
cv2.imshow('back', back_image)
cv2.imshow('mask and', mask_ANDed)
cv2.imshow('mask or', mask_ORed)
cv2.imshow('mask xor', mask_XORed)
cv2.imshow('mask inv', mask_Inverted)

cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-1c1a309e1db8> in <module>()
#       2 mask_image = cv2.imread('./images/mask_python.png')
#       3 back_image = cv2.imread('./images/iceberg.png')
# ----> 4 mask_image = cv2.resize(mask_image, (300,400))
#       5 back_image = cv2.resize(back_image, (300,400))
#       6
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %% [markdown]
# ## 13.7 원하는 색깔 픽셀만 뽑아 보자

# %%
import numpy as np
import cv2

image = cv2.imread('./images/mandrill.png')
image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

blue_low = np.array([80, 0, 0])
blue_high = np.array([130, 255, 255])

mask = cv2.inRange(image_hsv, blue_low, blue_high)

cv2.imshow('original', image)
cv2.imshow('mask', mask)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-0d1a60c316c2> in <module>()
#       3
#       4 image = cv2.imread('./images/mandrill.png')
# ----> 5 image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
#       6
#       7 blue_low = np.array([80, 0, 0])
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
extracted = cv2.bitwise_and(image, image, mask=mask)

# %% [markdown]
# ## 13.8 이미지에 필터를 씌워 보자

# %%
kernel = np.ones((3,3),np.float32)/9

# %%
filter2D(src, ddepth, kernel[, dst[, anchor[, delta[, borderType]]]])

# %%
averaged = cv2.filter2D(img, -1, kernel)

# %%
import numpy as np
import cv2

org = cv2.imread('./images/mandrill.png', 1)

kernel1 = np.ones((3,3), np.float32) / 9
kernel2 = np.ones((9,9), np.float32) / 81

averaged33 = cv2.filter2D(org, -1, kernel1)
averaged99 = cv2.filter2D(org, -1, kernel2)

cv2.imshow('original', org)
cv2.imshow('filtered1', averaged33)
cv2.imshow('filtered2', averaged99)

cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-d904f79927f5> in <module>()
#       7 kernel2 = np.ones((9,9), np.float32) / 81
#       8
# ----> 9 averaged33 = cv2.filter2D(org, -1, kernel1)
#      10 averaged99 = cv2.filter2D(org, -1, kernel2)
#      11
#
# error: OpenCV(4.1.2) /io/opencv/modules/core/src/matrix.cpp:757: error: (-215:Assertion failed) dims <= 2 && step[0] > 0 in function 'locateROI'

# %% [markdown]
# ## 13.9 OpenCV로 이미지 필터링하기

# %%
dst=cv.GaussianBlur(src, ksize, sigmaX[, dst[, sigmaY[, borderType]]])

# %%
import numpy as np
import cv2

org = cv2.imread('./images/mandrill.png', 1)

averaged33 = cv2.GaussianBlur(org, (3,3), 1)
averaged99 = cv2.GaussianBlur(org, (9,9), 1)

cv2.imshow('original', org)
cv2.imshow('Gaussian 33', averaged33)
cv2.imshow('Gaussian 99', averaged99)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-742520d3462d> in <module>()
#       4 org = cv2.imread('./images/mandrill.png', 1)
#       5
# ----> 6 averaged33 = cv2.GaussianBlur(org, (3,3), 1)
#       7 averaged99 = cv2.GaussianBlur(org, (9,9), 1)
#       8
#
# error: OpenCV(4.1.2) /io/opencv/modules/core/src/matrix.cpp:757: error: (-215:Assertion failed) dims <= 2 && step[0] > 0 in function 'locateROI'

# %% [markdown]
# ## 13.10 다양한 흐림 필터로 잡음을 제거해 보자

# %%
original_image = cv2.imread('./images/salt_pepper.png', 0)
result_image = cv2.medianBlur(original_image,  5)

# %%
dst = bilateralFilter(src, d, sigmaColor, sigmaSpace[, dst[, borderType]])

# %%
import numpy as np
import cv2

original_image = cv2.imread('./images/mandrill.png', 1)
result_image1 = cv2.GaussianBlur(original_image,  (9,9), 1)
result_image2 = cv2.medianBlur(original_image,  9)
result_image3 = cv2.bilateralFilter(original_image,  9, 50, 50)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-d41486fd3a9e> in <module>()
#       3
#       4 original_image = cv2.imread('./images/mandrill.png', 1)
# ----> 5 result_image1 = cv2.GaussianBlur(original_image,  (9,9), 1)
#       6 result_image2 = cv2.medianBlur(original_image,  9)
#       7 result_image3 = cv2.bilateralFilter(original_image,  9, 50, 50)
#
# error: OpenCV(4.1.2) /io/opencv/modules/core/src/matrix.cpp:757: error: (-215:Assertion failed) dims <= 2 && step[0] > 0 in function 'locateROI'

# %% [markdown]
# ## 13.11 관심있는 곳만 남겨보자

# %%
ret, result_image = threshold(src_image, thresh_value, maxValue, thresh_option)

# %%
import cv2
global color_image, gray_image

# 트랙바가 변경되면 그 값을 임계치로 회색조 이미지를 이진화하여 창에 그림
def on_change_threshold(x):
   _, th_image = cv2.threshold(gray_image, x, 255, cv2.THRESH_BINARY)
   cv2.imshow('Thresholding', th_image)

# 윈도를 생성함
cv2.namedWindow('Thresholding')
cv2.createTrackbar('threshold', 'Thresholding', 0, 255, on_change_threshold)

# %%
# 촛불 이미지를 읽고, 회색조 이미지를 준비함
color_image = cv2.imread('./images/candles.jpg', cv2.IMREAD_COLOR)
gray_image = cv2.cvtColor(color_image, cv2.COLOR_BGR2GRAY)

# 처음에는 원본 이미지를 그림 (트랙바를 변경하면 임계치에 따라 이진화 결과 출력)
cv2.imshow('Thresholding', color_image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def on_change_threshold(x):
   _, th_image = cv2.threshold(color_image, x, 255, cv2.THRESH_BINARY)
   cv2.imshow('Thresholding', th_image)

# %%
# image를 회색조로 읽어들인다.
img_gray = cv2.imread('./images/green_back.png', cv2.IMREAD_GRAYSCALE)

# adaptiveThreshold를 적용한다
# 주변 9x9 픽셀 공간의 평균값 - 5가 임계치가 되고, 이보다 크면 255, 그렇지 않으면 0
img_edge = cv2.adaptiveThreshold(img_gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C,
                                cv2.THRESH_BINARY,   blockSize=9,   C= 0)

# 결과는 윤곽선 픽셀이 드러난다
cv2.imshow('edge', img_edge)

# %%
import numpy as np
import cv2

img1 = cv2.imread('./images/green_back.png')   # 전경 이미지 읽기
img2 = cv2.imread('./images/iceberg.png')      # 배경 이미지 읽기
mask_image = cv2.resize(mask_image, (300,400))
back_image = cv2.resize(back_image, (300,400))

img_hsv = cv2.cvtColor(img1, cv2.COLOR_BGR2HSV) # HSV 공간으로 옮김
l_bound = np.array([40, 100, 50])               # 녹색 색상의 하한
u_bound = np.array([80, 255, 255])              # 녹색 색상의 상한
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-72484d2bfa69> in <module>()
#       4 img1 = cv2.imread('./images/green_back.png')   # 전경 이미지 읽기
#       5 img2 = cv2.imread('./images/iceberg.png')      # 배경 이미지 읽기
# ----> 6 mask_image = cv2.resize(mask_image, (300,400))
#       7 back_image = cv2.resize(back_image, (300,400))
#       8
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
def on_change_threshold(x):
   _, th_image = cv2.threshold(color_image, x, 255, cv2.THRESH_BINARY)
   cv2.imshow('Thresholding', th_image)

# %% [markdown]
# ## 13.12 윤곽선을 더 잘 뽑아 낼 수 있을까

# %%
cv2.adaptiveThreshold(img, value, method, thresholdType, blocksize, C)

# %%
img = cv2.imread('./images/book.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY)

cv2.imshow('gray', gray)
cv2.imshow('binary', thresh)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-10-2057a7280659> in <module>()
#       1 img = cv2.imread('./images/book.png')
# ----> 2 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       3 _, thresh = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY)
#       4
#       5 cv2.imshow('gray', gray)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ## LAB13-1
# ## 합성 사진 만들기

# %%
img_hsv = cv2.cvtColor(img1, cv2.COLOR_BGR2HSV) # HSV 공간으로 
l_bound = np.array([40, 100, 50])               # 녹색 색상 하한
u_bound = np.array([80, 255, 255])              # 녹색 색상 상한

mask = cv2.inRange(img_hsv, l_bound, u_bound)   # 녹색 픽셀 찾기
mask_inv = cv2.bitwise_not(mask)                # 녹색 아닌 픽셀 찾기

# %%
import numpy as np
import cv2

img1 = cv2.imread('./images/green_back.png')   # 전경 이미지 읽기
img2 = cv2.imread('./images/iceberg.png')      # 배경 이미지 읽기
mask_image = cv2.resize(mask_image, (300,400))
back_image = cv2.resize(back_image, (300,400))

img_hsv = cv2.cvtColor(img1, cv2.COLOR_BGR2HSV) # HSV 공간으로 옮김
l_bound = np.array([40, 100, 50])               # 녹색 색상의 하한
u_bound = np.array([80, 255, 255])              # 녹색 색상의 상한

# %%
mask = cv2.inRange(img_hsv, l_bound, u_bound)    # 녹색 픽셀 찾기
mask_inv = cv2.bitwise_not(mask)                 # 녹색이 아닌 픽셀 찾기

# 녹색 픽셀들만 추출하기
extracted = cv2.bitwise_and(img1, img1, mask = mask) 
# 녹색 아닌 픽셀만 추출하기
removed = cv2.bitwise_and(img1, img1, mask = mask_inv)   
# 녹색과 겹치는 배경 추출
background = cv2.bitwise_and(img2, img2, mask=mask)   
# 녹색 제거 전경 + 배경   
merged = cv2.bitwise_or(removed, background)
             
cv2.imshow('mask', mask)
cv2.imshow('mask_inv', mask_inv)
cv2.imshow('removed', removed)
cv2.imshow('merged', merged)

cv2.waitKey(0)

# %% [markdown]
#
# ## LAB13-2
# ## 텍스트 데이터 추출을 위한 준비

# %%
img = cv2.imread('./images/book.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY)

cv2.imshow('gray', gray)
cv2.imshow('binary', thresh)

# %%
import numpy as np
import cv2

# %%
img = cv2.imread('./images/book.png')

# 잡음은 제거하면서 특징은 유지할 수 있는 양방향 필터 적용
blur_bilateral = cv2.bilateralFilter(img, 11, 75, 75)   

# 회색조로 변환
gray = cv2.cvtColor(blur_bilateral, cv2.COLOR_BGR2GRAY) 

# 인근 픽셀과 비교한 이진화
thresh = cv2.adaptiveThreshold(gray, 255,                            
         cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 15, 7)

cv2.imshow('original', img)
cv2.imshow('bilateral', blur_bilateral)
cv2.imshow('gray', gray)
cv2.imshow('binary', thresh)

cv2.waitKey(0)
