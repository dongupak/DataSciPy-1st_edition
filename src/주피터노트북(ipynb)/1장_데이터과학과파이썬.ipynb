# %% [markdown]
# # 생능출판사 (가칭)"데이터과학 파이썬" 코드 1장
# ## chapter 1
# ### 데이터 과학과 파이썬

# %% [markdown]
# ### 1.5 프로그래밍을 꼭 알아야 하나?

# %%
from collections import Counter 

f = open("d:/mobydick.txt", encoding="utf-8") 
count = Counter(f.read().split()) 
print("단어 출현 횟수 :", count)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-4dc0d0102044> in <module>()
#       1 from collections import Counter
#       2
# ----> 3 f = open("d:/mobydick.txt", encoding="utf-8")
#       4 count = Counter(f.read().split())
#       5 print("단어 출현 횟수 :", count)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'd:/mobydick.txt'

# %% [markdown]
# ### 1.8 파이썬 인터프리터를 사용해 보기

# %%
print('Hello Python!!')
# Out:
# Hello Python!!

# %%
5 + 6
# Out:
# 11

# %%
반지름 = 4
면적 = 3.14 * 반지름 * 반지름
print(면적)
# Out:
# 50.24

# %% [markdown]
# 1.10 주석으로 이해하기 쉬운 코드를 만들기

# %%
# 다음 코드는 반지름을 이용하여 원의 면적을 출력하는 코드이다
반지름 = 4                     # 반지름의 값을 저장합니다.
면적 = 3.14 * 반지름 * 반지름   # 반지름의 값을 이용하여 원의 면적을 구합니다.
print(면적)                    # 면적을 화면에 출력합니다.
# Out:
# 50.24

# %%
# 여러 줄의 주석을 사용할 때
# 해시 표시를 문장의 첫 줄에 넣어서
# 주석을 사용할 수 있습니다.

# %%
'''
작은따옴표를 이용하여 여러 줄 주석을 만드는 방법입니다
이 방식으로 주석을 만들면
여러 줄에 걸친 주석을 남길 수 있습니다
'''

# %%
"""
혹은 이와 같이 큰따옴표를 이용할 수도 있습니다.
큰따옴표를 사용해도 작은따옴표를 사용하는 것과 동일합니다.
"""

# %% [markdown]
#  1.11 무작정 계산부터 해보자

# %%
 2 + 3
# Out:
# 5

# %%
print(2 + 3)

# %%
print(2 - 3)
# Out:
# -1

# %%
print(2 * 3)

# %%
print(2 / 3)
# Out:
# 0.6666666666666666

# %%
print(2345 * 9876 - 5678)
# Out:
# 23153542

# %%
print(123456789123456789 * 123456789123456789)
# Out:
# 15241578780673678515622620750190521

# %% [markdown]
#
#  1.12 print() 함수로 원하는 메시지 출력해 보기

# %%
'Hello'
# Out:
# 'Hello'

# %%
print('Hello')
# Out:
# Hello

# %%
print("즐거운 " + "파이썬 익히기")
# Out:
# 즐거운 파이썬 익히기

# %%
print("반가워요 " * 20)
# Out:
# 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요 반가워요

# %%
print("100" + "200")
# Out:
# 100200

# %%
print(100 + 200)
# Out:
# 300

# %%
multiline_string = """This is a multiline string
with "newline" characters
within the string"""
print(multiline_string)
# Out:
# This is a multiline string
# with "newline" characters
# within the string

# %% [markdown]
#  1.14 터틀 그래픽으로 눈에 보이는 결과를 만들어 보자

# %%
import turtle            # turtle 모듈을 사용하기 위해 준비한다
t = turtle.Turtle()      # turtle 모듈에 있는 Turtle 클래스 객체를 t로 생성한다
t.shape('turtle')        # Turtle 클래스 객체인 t의 모양을 그리기 모양을 설정한다
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-17-67fd98970da4> in <module>()
#       1 import turtle            # turtle 모듈을 사용하기 위해 준비한다
# ----> 2 t = turtle.Turtle()      # turtle 모듈에 있는 Turtle 클래스 객체를 t로 생성한다
#       3 t.shape('turtle')        # Turtle 클래스 객체인 t의 모양을 그리기 모양을 설정한다
#
# /usr/lib/python3.6/turtle.py in __init__(self, shape, undobuffersize, visible)
#    3810                  visible=_CFG["visible"]):
#    3811         if Turtle._screen is None:
# -> 3812             Turtle._screen = Screen()
#    3813         RawTurtle.__init__(self, Turtle._screen,
#    3814                            shape=shape,
#
# /usr/lib/python3.6/turtle.py in Screen()
#    3660     else return the existing one."""
#    3661     if Turtle._screen is None:
# -> 3662         Turtle._screen = _Screen()
#    3663     return Turtle._screen
#    3664
#
# ...

# %%
t.forward(100)    # 거북이를 전진(forward)시키는 명령어로 100픽셀 만큼 이동

# %%
t.left(90)       # 거북이를 왼쪽으로(left) 90도 회전시키는 명령어 
t.forward(50)

# %% [markdown]
#  1.15 오류가 발생할 수 있다

# %%
PRINT("Hello World")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-6a2b26b908b8> in <module>()
# ----> 1 PRINT("Hello World")
#
# NameError: name 'PRINT' is not defined

# %%
print(Good Bye)
# Out:
#   File "<ipython-input-19-9bee25ed4faf>", line 1
#     print(Good Bye)
#                  ^
# SyntaxError: invalid syntax

# %%
print("안녕하세요? 여러분")

# %%
print("저는 파이썬을 무척 좋아합니다.")

# %%
print("9*8은", 9*8, "입니다.")

# %%
print("안녕히 계세요.")

# %%
import turtle 
t=turtle.Turtle() 
t.shape("turtle") 
t.forward(100) 
t.left(120) 
t.forward(100) 
t.left(120) 
t.forward(100)

# %%
from collections import Counter 
 
f = open("d:/mobydick.txt", encoding="utf-8") 
count = Counter(f.read().split()) 
print("단어 출현 횟수 :", count)
